# %%
import pandas as pandas

# %%
df = pandas.read_csv("/content/Gapminder.csv", error_bad_lines=False, sep=";")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.rename(columns={"country":"Pais","continent":"Continente","year":"Ano","lifeExp":"ExpVida","pop":"PopTotal","gdpPercap":"PIB"})
# Out:
#              Pais Continente   Ano  ExpVida  PopTotal         PIB
# 0     Afghanistan       Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan       Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan       Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan       Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan       Asia  1972   36.088  13079460  739.981106
# ...           ...        ...   ...      ...       ...         ...
# 3307     Zimbabwe     Africa  1987   62.351   9216418  706.157306
# 3308     Zimbabwe     Africa  1992   60.377  10704340  693.420786
# 3309     Zimbabwe     Africa  1997   46.809  11404948  792.449960
# 3310     Zimbabwe     Africa  2002   39.989  11926563  672.038623
# 3311     Zimbabwe     Africa  2007   43.487  12311143  469.709298
#
# [3312 rows x 6 columns]

# %%
df = df.rename(columns={"country":"Pais","continent":"Continente","year":"Ano","lifeExp":"ExpVida","pop":"PopTotal","gdpPercap":"PIB"})

# %%
df.head(10)
# Out:
#           Pais Continente   Ano  ExpVida  PopTotal         PIB
# 0  Afghanistan       Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan       Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan       Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan       Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan       Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan       Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan       Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan       Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan       Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan       Asia  1997   41.763  22227415  635.341351

# %%
df.shape
# Out:
# (3312, 6)

# %%
df.columns
# Out:
# Index(['Pais', 'Continente', 'Ano', 'ExpVida', 'PopTotal', 'PIB'], dtype='object')

# %%
df.dtypes
# Out:
# Pais           object
# Continente     object
# Ano             int64
# ExpVida       float64
# PopTotal        int64
# PIB           float64
# dtype: object

# %%
df.tail(15)
# Out:
#           Pais Continente   Ano  ExpVida  PopTotal          PIB
# 3297    Zambia     Africa  1997   40.238   9417789  1071.353818
# 3298    Zambia     Africa  2002   39.193  10595811  1071.613938
# 3299    Zambia     Africa  2007   42.384  11746035  1271.211593
# 3300  Zimbabwe     Africa  1952   48.451   3080907   406.884115
# 3301  Zimbabwe     Africa  1957   50.469   3646340   518.764268
# 3302  Zimbabwe     Africa  1962   52.358   4277736   527.272182
# 3303  Zimbabwe     Africa  1967   53.995   4995432   569.795071
# 3304  Zimbabwe     Africa  1972   55.635   5861135   799.362176
# 3305  Zimbabwe     Africa  1977   57.674   6642107   685.587682
# 3306  Zimbabwe     Africa  1982   60.363   7636524   788.855041
# 3307  Zimbabwe     Africa  1987   62.351   9216418   706.157306
# 3308  Zimbabwe     Africa  1992   60.377  10704340   693.420786
# 3309  Zimbabwe     Africa  1997   46.809  11404948   792.449960
# 3310  Zimbabwe     Africa  2002   39.989  11926563   672.038623
# ...

# %%
df.describe()
# Out:
#                Ano      ExpVida      PopTotal            PIB
# count  3312.000000  3312.000000  3.312000e+03    3312.000000
# mean   1980.301630    65.246871  3.161489e+07   11317.115805
# std      16.927294    11.768412  1.041193e+08   11369.142739
# min    1950.000000    23.599000  5.941200e+04     241.165876
# 25%    1967.000000    58.337500  2.678572e+06    2514.625266
# 50%    1982.000000    69.610000  7.557218e+06    7838.505123
# 75%    1996.000000    73.657750  1.958522e+07   17357.879170
# max    2007.000000    82.670000  1.318683e+09  113523.132900

# %%
df["Continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
Oceania = df.loc[df["Continente"] == "Oceania"]

# %%
Asia = df.loc[df["Continente"] == "Asia"]

# %%
Europa = df.loc[df["Continente"] == "Europa"]

# %%
Oceania.tail(10)
# Out:
#                  Pais Continente   Ano  ExpVida  PopTotal           PIB
# 2159      New Zealand    Oceania  2007   80.204   4115771  25185.009110
# 2692  Solomon Islands    Oceania  1967   52.964    151000   1304.598869
# 2693  Solomon Islands    Oceania  1972   55.506    174500    864.974253
# 2694  Solomon Islands    Oceania  1977   58.005    207339   1169.543666
# 2695  Solomon Islands    Oceania  1982   58.736    250516   1467.396037
# 2696  Solomon Islands    Oceania  1987   55.785    300694   1783.648762
# 2697  Solomon Islands    Oceania  1992   58.270    358713   2109.894257
# 2698  Solomon Islands    Oceania  1997   60.708    424265   2252.491044
# 2699  Solomon Islands    Oceania  2002   62.274    494786   1530.496068
# 2700  Solomon Islands    Oceania  2007   63.570    566842   1829.317402

# %%
df.groupby("Ano")["ExpVida"].nunique()
# Out:
# Ano
# 1950     38
# 1951     24
# 1952    143
# 1953     24
# 1954     24
# 1955     24
# 1956     24
# 1957    144
# 1958     24
# 1959     25
# 1960     26
# 1961     25
# 1962    150
# 1963     24
# 1964     24
# 1965     26
# 1966     26
# 1967    155
# 1968     27
# 1969     27
# 1970     27
# 1971     27
# 1972    168
# 1973     32
# 1974     25
# 1975     27
# 1976     27
# 1977    171
# 1978     27
# 1979     27
# 1980     27
# 1981     26
# 1982    170
# 1983     27
# 1984     27
# 1985     27
# 1986     27
# 1987    170
# 1988     26
# 1989     26
# 1990     30
# 1991     33
# 1992    182
# 1993     33
# 1994     33
# 1995     33
# 1996     33
# 1997    184
# 1998     33
# 1999     33
# 2000     30
# 2001     33
# 2002    187
# 2003     33
# 2004     32
# 2005     30
# 2006     18
# 2007    183
# Name: ExpVida, dtype: int64

# %%
df.groupby("Pais")["PopTotal"].nunique()
# Out:
# Pais
# Afghanistan           12
# Albania               12
# Algeria               12
# Angola                12
# Argentina             12
#                       ..
# Vietnam               12
# West Bank and Gaza    12
# Yemen, Rep.           12
# Zambia                12
# Zimbabwe              12
# Name: PopTotal, Length: 187, dtype: int64

# %%
df.groupby("Continente")["Pais"].nunique()
# Out:
# Continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: Pais, dtype: int64

# %%
df.groupby("Ano")["ExpVida"].mean()
# Out:
# Ano
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283438
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...

# %%
df["PIB"].mean()
# Out:
# 11317.115804696648

# %%
df["PIB"].sum()
# Out:
# 37482287.5451553
